# %%
import pandas as pd 
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import init_notebook_mode, plot, iplot
import plotly.graph_objs as go
from surprise import Reader, Dataset, accuracy, SVD, SVDpp, SlopeOne, NMF, NormalPredictor, KNNBaseline, KNNBasic, KNNWithMeans, KNNWithZScore, BaselineOnly, CoClustering
from surprise.model_selection import KFold, cross_validate, train_test_split
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
ratingsCsv = pd.read_csv(r'C:\Users\Rodrigo\Documents\Data-Science-Project\Data Science\ratings.csv', sep=',',header=0, names=['userId','movieId','rating','timestamp'])
ratingsCsv.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
movieTitles = pd.read_csv(r'C:\Users\Rodrigo\Documents\Data-Science-Project\Data Science\movies.csv', header=0)
movieTitles.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratingsCsv = pd.merge(ratingsCsv, movieTitles, on='movieId')
ratingsCsv.head(1000)
#ratingsCsv.describe()
# Out:
#      userId  movieId  rating   timestamp              title  \
# 0         1        1     4.0   964982703   Toy Story (1995)
# 1         5        1     4.0   847434962   Toy Story (1995)
# 2         7        1     4.5  1106635946   Toy Story (1995)
# 3        15        1     2.5  1510577970   Toy Story (1995)
# 4        17        1     4.5  1305696483   Toy Story (1995)
# ..      ...      ...     ...         ...                ...
# 995     374      110     5.0   849089153  Braveheart (1995)
# 996     376      110     3.5  1364993995  Braveheart (1995)
# 997     379      110     5.0   847397381  Braveheart (1995)
# 998     380      110     4.0  1493419805  Braveheart (1995)
# 999     386      110     3.0   842610269  Braveheart (1995)
#
#                                           genres
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 1    Adventure|Animation|Children|Comedy|Fantasy
# 2    Adventure|Animation|Children|Comedy|Fantasy
# 3    Adventure|Animation|Children|Comedy|Fantasy
# 4    Adventure|Animation|Children|Comedy|Fantasy
# ..                                           ...
# 995                             Action|Drama|War
# 996                             Action|Drama|War
# 997                             Action|Drama|War
# 998                             Action|Drama|War
# 999                             Action|Drama|War
#
# [1000 rows x 6 columns]

# %%
ratingsCsv.head(1000)
# Out:
#      userId  movieId  rating   timestamp              title  \
# 0         1        1     4.0   964982703   Toy Story (1995)
# 1         5        1     4.0   847434962   Toy Story (1995)
# 2         7        1     4.5  1106635946   Toy Story (1995)
# 3        15        1     2.5  1510577970   Toy Story (1995)
# 4        17        1     4.5  1305696483   Toy Story (1995)
# ..      ...      ...     ...         ...                ...
# 995     374      110     5.0   849089153  Braveheart (1995)
# 996     376      110     3.5  1364993995  Braveheart (1995)
# 997     379      110     5.0   847397381  Braveheart (1995)
# 998     380      110     4.0  1493419805  Braveheart (1995)
# 999     386      110     3.0   842610269  Braveheart (1995)
#
#                                           genres
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 1    Adventure|Animation|Children|Comedy|Fantasy
# 2    Adventure|Animation|Children|Comedy|Fantasy
# 3    Adventure|Animation|Children|Comedy|Fantasy
# 4    Adventure|Animation|Children|Comedy|Fantasy
# ..                                           ...
# 995                             Action|Drama|War
# 996                             Action|Drama|War
# 997                             Action|Drama|War
# 998                             Action|Drama|War
# 999                             Action|Drama|War
#
# [1000 rows x 6 columns]

# %%
ratings = pd.DataFrame(ratingsCsv.groupby(['title'])['rating'].mean())
ratings.head()
# Out:
#                                          rating
# title
# '71 (2014)                                  4.0
# 'Hellboy': The Seeds of Creation (2004)     4.0
# 'Round Midnight (1986)                      3.5
# 'Salem's Lot (2004)                         5.0
# 'Til There Was You (1997)                   4.0

# %%
ratings['number_of_ratings'] = ratingsCsv.groupby('title')['rating'].count()
ratings.head()
# Out:
#                                          rating  number_of_ratings
# title
# '71 (2014)                                  4.0                  1
# 'Hellboy': The Seeds of Creation (2004)     4.0                  1
# 'Round Midnight (1986)                      3.5                  2
# 'Salem's Lot (2004)                         5.0                  1
# 'Til There Was You (1997)                   4.0                  2

# %%
ratings['rating'].hist(bins=50)

# %%
ratings['number_of_ratings'].hist(bins=60)

# %%
sns.jointplot(x='rating', y='number_of_ratings', data=ratings)

# %%
movie_matrix = ratingsCsv.pivot_table(index='userId', columns='title', values='rating')
movie_matrix.head()
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)  ...  Zulu (2013)  [REC] (2007)  \
# userId                                  ...
# 1                                  NaN  ...          NaN           NaN
# 2                                  NaN  ...          NaN           NaN
# 3                                  NaN  ...          NaN           NaN
# 4                                  NaN  ...          NaN           NaN
# 5                                  NaN  ...          NaN           NaN
#
# title   [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userId
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
# 5                 NaN                      NaN
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
#
# title   eXistenZ (1999)  xXx (2002)  xXx: State of the Union (2005)  \
# userId
# 1                   NaN         NaN                             NaN
# 2                   NaN         NaN                             NaN
# 3                   NaN         NaN                             NaN
# 4                   NaN         NaN                             NaN
# 5                   NaN         NaN                             NaN
#
# title   ¡Three Amigos! (1986)  À nous la liberté (Freedom for Us) (1931)
# userId
# 1                         4.0                                        NaN
# 2                         NaN                                        NaN
# 3                         NaN                                        NaN
# 4                         NaN                                        NaN
# 5                         NaN                                        NaN
#
# [5 rows x 9719 columns]

# %%
ratings.sort_values('number_of_ratings', ascending=False).head(10)
# Out:
#                                              rating  number_of_ratings
# title
# Forrest Gump (1994)                        4.164134                329
# Shawshank Redemption, The (1994)           4.429022                317
# Pulp Fiction (1994)                        4.197068                307
# Silence of the Lambs, The (1991)           4.161290                279
# Matrix, The (1999)                         4.192446                278
# Star Wars: Episode IV - A New Hope (1977)  4.231076                251
# Jurassic Park (1993)                       3.750000                238
# Braveheart (1995)                          4.031646                237
# Terminator 2: Judgment Day (1991)          3.970982                224
# Schindler's List (1993)                    4.225000                220

# %%
toyStoryRating = movie_matrix['Pulp Fiction (1994)']

# %%
toyStoryRating.tail()
# Out:
# userId
# 606    5.0
# 607    3.0
# 608    5.0
# 609    4.0
# 610    5.0
# Name: Pulp Fiction (1994), dtype: float64

# %%
correlationToyStory = movie_matrix.corrwith(toyStoryRating)

# %%
correlationToyStory.head()
# Out:
# title
# '71 (2014)                                NaN
# 'Hellboy': The Seeds of Creation (2004)   NaN
# 'Round Midnight (1986)                    NaN
# 'Salem's Lot (2004)                       NaN
# 'Til There Was You (1997)                 NaN
# dtype: float64

# %%
corr_Toy = pd.DataFrame(correlationToyStory, columns=['correlation'])
corr_Toy.dropna(inplace=True)
corr_Toy.head()
# Out:
#                                 correlation
# title
# 'burbs, The (1989)                -0.187323
# (500) Days of Summer (2009)       -0.044034
# *batteries not included (1987)    -0.738549
# ...And Justice for All (1979)     -0.188982
# 10 Cent Pistol (2015)              1.000000

# %%
corr_Toy = corr_Toy.join(ratings['number_of_ratings'])
corr_Toy.head()
corr_Toy[corr_Toy['number_of_ratings'] > 50].sort_values(by='correlation', ascending=False).head(10)
# Out:
#                                  correlation  number_of_ratings
# title
# Pulp Fiction (1994)                 1.000000                307
# Wolf of Wall Street, The (2013)     0.579915                 54
# Fight Club (1999)                   0.543465                218
# Kill Bill: Vol. 1 (2003)            0.504147                131
# Interstellar (2014)                 0.503411                 73
# True Romance (1993)                 0.484209                 65
# Blair Witch Project, The (1999)     0.468343                 64
# Requiem for a Dream (2000)          0.463093                 96
# Brazil (1985)                       0.462131                 59
# Mary Poppins (1964)                 0.458205                 71

# %%
#Usando generos para melhorar sugestão

# %%
ratingsCsv.head(1000)
# Out:
#      userId  movieId  rating   timestamp              title  \
# 0         1        1     4.0   964982703   Toy Story (1995)
# 1         5        1     4.0   847434962   Toy Story (1995)
# 2         7        1     4.5  1106635946   Toy Story (1995)
# 3        15        1     2.5  1510577970   Toy Story (1995)
# 4        17        1     4.5  1305696483   Toy Story (1995)
# ..      ...      ...     ...         ...                ...
# 995     374      110     5.0   849089153  Braveheart (1995)
# 996     376      110     3.5  1364993995  Braveheart (1995)
# 997     379      110     5.0   847397381  Braveheart (1995)
# 998     380      110     4.0  1493419805  Braveheart (1995)
# 999     386      110     3.0   842610269  Braveheart (1995)
#
#                                           genres
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 1    Adventure|Animation|Children|Comedy|Fantasy
# 2    Adventure|Animation|Children|Comedy|Fantasy
# 3    Adventure|Animation|Children|Comedy|Fantasy
# 4    Adventure|Animation|Children|Comedy|Fantasy
# ..                                           ...
# 995                             Action|Drama|War
# 996                             Action|Drama|War
# 997                             Action|Drama|War
# 998                             Action|Drama|War
# 999                             Action|Drama|War
#
# [1000 rows x 6 columns]

# %%
recomendations = corr_Toy[corr_Toy['number_of_ratings'] > 50].sort_values(by='correlation', ascending=False)
recomendations.head()
# Out:
#                                  correlation  number_of_ratings
# title
# Pulp Fiction (1994)                 1.000000                307
# Wolf of Wall Street, The (2013)     0.579915                 54
# Fight Club (1999)                   0.543465                218
# Kill Bill: Vol. 1 (2003)            0.504147                131
# Interstellar (2014)                 0.503411                 73

# %%
recomendations.describe()
# Out:
#        correlation  number_of_ratings
# count   437.000000         437.000000
# mean      0.077208          93.162471
# std       0.182897          46.196366
# min      -0.402530          51.000000
# 25%      -0.051788          61.000000
# 50%       0.079640          77.000000
# 75%       0.189543         109.000000
# max       1.000000         329.000000

# %%
recomendations = pd.merge(recomendations, movieTitles, on='title')
recomendations.describe()
# Out:
#        correlation  number_of_ratings        movieId
# count   438.000000         438.000000     438.000000
# mean      0.077436          93.068493   10788.335616
# std       0.182750          46.185378   22644.909198
# min      -0.402530          51.000000       1.000000
# 25%      -0.051696          60.250000     733.750000
# 50%       0.079854          77.000000    2002.500000
# 75%       0.189424         109.000000    4946.250000
# max       1.000000         329.000000  122904.000000

# %%
recomendations = recomendations.drop('movieId', axis=1)
recomendations.head()
# Out:
#                              title  correlation  number_of_ratings  \
# 0              Pulp Fiction (1994)     1.000000                307
# 1  Wolf of Wall Street, The (2013)     0.579915                 54
# 2                Fight Club (1999)     0.543465                218
# 3         Kill Bill: Vol. 1 (2003)     0.504147                131
# 4              Interstellar (2014)     0.503411                 73
#
#                         genres
# 0  Comedy|Crime|Drama|Thriller
# 1           Comedy|Crime|Drama
# 2  Action|Crime|Drama|Thriller
# 3        Action|Crime|Thriller
# 4                  Sci-Fi|IMAX

# %%
def genreCompatibility(genresSet1, genresSet2):
    #print(genresSet2)
    genresSet1 = genresSet1.strip()
    genresSet1 = genresSet1.split('|')
    #print(genresSet1)
    genresSet2 = genresSet2.strip()
    genresSet2 = genresSet2.split('|')
    compatibility = 0
    for genre in genresSet1:
        if genre in genresSet2:
            compatibility = compatibility + 1
    return compatibility
    #print(compatibility)

# %%
def adjustCorrelation(dataframe, movieTitle):
    #print(movieTitles.loc[movieTitles['title'] == movieTitle])
    movie = movieTitles.loc[movieTitles['title'] == movieTitle]
    movieGenres = movie['genres'].values[0] 
    #genreCompatibility(movie['genres'].values[0] , 'Adventure|Animation|Children|Comedy|Fantasy')
    for index, row in dataframe.iterrows():
        cmp = genreCompatibility(movieGenres, row['genres'])
        dataframe.at[index,'correlation'] =  row['correlation'] + cmp

# %%
adjustCorrelation(recomendations, 'Pulp Fiction (1994)')

# %%
recomendations = recomendations.sort_values(by='correlation', ascending=False)
recomendations.head(50)
# Out:
#                                                  title  correlation  \
# 0                                  Pulp Fiction (1994)     5.000000
# 99                                        Fargo (1996)     4.205925
# 337                                    Bad Boys (1995)     3.938797
# 1                      Wolf of Wall Street, The (2013)     3.579915
# 2                                    Fight Club (1999)     3.543465
# 12                                Trainspotting (1996)     3.437714
# 16            Lock, Stock & Two Smoking Barrels (1998)     3.407869
# 30   Léon: The Professional (a.k.a. The Professiona...     3.347574
# 32                                   Get Shorty (1995)     3.341688
# 47                                Departed, The (2006)     3.306734
# 90                          Clockwork Orange, A (1971)     3.216907
# 91                                  Taxi Driver (1976)     3.215408
# 95                             Mulholland Drive (2001)     3.208695
# 101                               Blood Diamond (2006)     3.204755
# 113                                    Face/Off (1997)     3.185094
# 120                City of God (Cidade de Deus) (2002)     3.171722
# 131                                      Snatch (2000)     3.163064
# 216                                Training Day (2001)     3.080294
# 222                                   Inception (2010)     3.077961
# 228                                     RoboCop (1987)     3.072753
# 289                                     Traffic (2000)     2.992175
# 360                             Few Good Men, A (1992)     2.903946
# 394                                       Ghost (1990)     2.859095
# 399                    Clear and Present Danger (1994)     2.841442
# 419                       Beverly Hills Cop III (1994)     2.790108
# 431                               Lethal Weapon (1987)     2.677921
# 3                             Kill Bill: Vol. 1 (2003)     2.504147
# 5                                  True Romance (1993)     2.484209
# 6                      Blair Witch Project, The (1999)     2.468343
# 10                         Fish Called Wanda, A (1988)     2.449683
# 11                    Grand Budapest Hotel, The (2014)     2.447946
# 14                            Kill Bill: Vol. 2 (2004)     2.421685
# 15                          Usual Suspects, The (1995)     2.411700
# 20                               Reservoir Dogs (1992)     2.394687
# 23                                 Mystic River (2003)     2.370950
# 24                              Children of Men (2006)     2.369199
# 25                               Godfather, The (1972)     2.364778
# 26          Life Is Beautiful (La Vita è bella) (1997)     2.364001
# 31                    Silence of the Lambs, The (1991)     2.345282
# 33                          Slumdog Millionaire (2008)     2.335160
# 43                               Eyes Wide Shut (1999)     2.314169
# 45                                High Fidelity (2000)     2.311907
# 46                                      Ed Wood (1994)     2.311552
# 50                         Natural Born Killers (1994)     2.296247
# 52                          From Dusk Till Dawn (1996)     2.289071
# 57                          Shakespeare in Love (1998)     2.280398
# 63                       No Country for Old Men (2007)     2.268699
# 65                          Grosse Pointe Blank (1997)     2.266234
# 66                                 Donnie Darko (2001)     2.265083
# 68                           American History X (1998)     2.262790
#
#      number_of_ratings                                           genres
# 0                  307                      Comedy|Crime|Drama|Thriller
# 99                 181                      Comedy|Crime|Drama|Thriller
# 337                 51               Action|Comedy|Crime|Drama|Thriller
# 1                   54                               Comedy|Crime|Drama
# 2                  218                      Action|Crime|Drama|Thriller
# 12                 102                               Comedy|Crime|Drama
# 16                  67                            Comedy|Crime|Thriller
# 30                 133                      Action|Crime|Drama|Thriller
# 32                  89                            Comedy|Crime|Thriller
# 47                 107                             Crime|Drama|Thriller
# 90                 120                      Crime|Drama|Sci-Fi|Thriller
# 91                 104                             Crime|Drama|Thriller
# 95                  51           Crime|Drama|Film-Noir|Mystery|Thriller
# 101                 53        Action|Adventure|Crime|Drama|Thriller|War
# 113                 77                      Action|Crime|Drama|Thriller
# 120                 75            Action|Adventure|Crime|Drama|Thriller
# 131                 93                            Comedy|Crime|Thriller
# 216                 51                             Crime|Drama|Thriller
# 222                143  Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX
# 228                 70               Action|Crime|Drama|Sci-Fi|Thriller
# 289                 70                             Crime|Drama|Thriller
# 360                 57                             Crime|Drama|Thriller
# 394                115            Comedy|Drama|Fantasy|Romance|Thriller
# 399                110                      Action|Crime|Drama|Thriller
# 419                 59                     Action|Comedy|Crime|Thriller
# 431                 75                        Action|Comedy|Crime|Drama
# 3                  131                            Action|Crime|Thriller
# 5                   65                                   Crime|Thriller
# 6                   64                            Drama|Horror|Thriller
# 10                  71                                     Comedy|Crime
# 11                  52                                     Comedy|Drama
# 14                 110                            Action|Drama|Thriller
# 15                 204                           Crime|Mystery|Thriller
# 20                 131                           Crime|Mystery|Thriller
# 23                  52                              Crime|Drama|Mystery
# 24                  64           Action|Adventure|Drama|Sci-Fi|Thriller
# 25                 192                                      Crime|Drama
# 26                  88                         Comedy|Drama|Romance|War
# 31                 279                            Crime|Horror|Thriller
# 33                  71                              Crime|Drama|Romance
# 43                  53                           Drama|Mystery|Thriller
# 45                  75                             Comedy|Drama|Romance
# 46                  70                                     Comedy|Drama
# 50                  92                            Action|Crime|Thriller
# 52                  55                    Action|Comedy|Horror|Thriller
# 57                  92                             Comedy|Drama|Romance
# 63                  64                                      Crime|Drama
# 65                  59                             Comedy|Crime|Romance
# 66                 109                    Drama|Mystery|Sci-Fi|Thriller
# 68                 129                                      Crime|Drama

# %%
ratings = pd.DataFrame(ratingsCsv.groupby(['genres'])['title'].count())
ratings.head(120)
# Out:
#                                                  title
# genres
# (no genres listed)                                  47
# Action                                             186
# Action|Adventure                                   555
# Action|Adventure|Animation                          42
# Action|Adventure|Animation|Children                 39
# ...                                                ...
# Action|Adventure|Fantasy|Thriller                   72
# Action|Adventure|Fantasy|War                         1
# Action|Adventure|Horror                              1
# Action|Adventure|Horror|Mystery|Sci-Fi|Thriller      3
# Action|Adventure|Horror|Sci-Fi                     127
#
# [120 rows x 1 columns]

# %%
#Usando a biblioteca surprise par melhorar

# %%
reader = Reader()
ratingsCsv = ratingsCsv.drop(['title', 'genres'], axis=1)
ratingsCsv.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        1     4.0   964982703
# 1       5        1     4.0   847434962
# 2       7        1     4.5  1106635946
# 3      15        1     2.5  1510577970
# 4      17        1     4.5  1305696483

# %%
benchmark = []
data = Dataset.load_from_df(ratingsCsv[['userId', 'movieId', 'rating']], reader)
for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
    results = cross_validate(algorithm, data, measures=['RMSE'], cv=3, verbose=False)
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)

pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')

# %%
#Vamos usar o melhor algoritmo que foi o SVDpp que teve o menor erro

# %%
kf = KFold(n_splits=5)
data = Dataset.load_from_df(ratingsCsv[['userId', 'movieId', 'rating']], reader)

# %%
svdpp = BaselineOnly()

# %%
for trainset, testset in kf.split(data):
    svdpp.fit(trainset)
    predictions = svdpp.test(testset)
    accuracy.rmse(predictions, verbose=True)

# %%
ratingsCsv[ratingsCsv['userId']==1].head()

# %%
svdpp.predict(1,302,3)

# %%
movieTitles['estimation'] = movieTitles['movieId'].apply(lambda x: svdpp.predict(1, x).est)

# %%
movieTitles.sort_values('estimation', ascending=False)
